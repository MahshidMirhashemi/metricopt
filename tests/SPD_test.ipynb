# %%
import sys, os
sys.path.append(os.path.abspath(".."))
import numpy as np
from spaces.SPD import SymmetricPositiveDefinite

# %%
space = SymmetricPositiveDefinite(dimension=3) 
S = space.sample(n_samples=10, seed=0, dtype=np.float64)  # shape (n, dim, dim)
np.set_printoptions(precision=20, suppress=False)      # print decimals with controlled precision
print(S.shape)
print(S)
# Out:
# (10, 3, 3)
# [[[ 0.0825917003472736    0.03014700526647381   0.374753596992348   ]
#   [ 0.03014700526647381   2.489765494561261     1.6278818760593137  ]
#   [ 0.374753596992348     1.6278818760593137    2.784682066598488   ]]
#
#  [[ 0.5409356880242985   -1.710021312178788    -0.5385704122347367  ]
#   [-1.710021312178788     5.468160839858067     1.5665961972491511  ]
#   [-0.5385704122347367    1.5665961972491511    1.8963288061010766  ]]
#
#  [[ 0.02592408701424609   0.22001371865482044   0.14546736055739506 ]
#   [ 0.22001371865482044   2.210066431936526     1.2896059110592664  ]
#   [ 0.14546736055739506   1.2896059110592664    2.6239670295165274  ]]
#
#  [[ 1.9642589408525977   -1.415000303673934     0.758006025494451   ]
#   [-1.415000303673934     1.2720189341440304   -0.43814207518571413 ]
#   [ 0.758006025494451    -0.43814207518571413   1.3181243933993751  ]]
#
#  [[ 0.026992716451802175  0.24536267655227767   0.22112006793345843 ]
#   [ 0.24536267655227767   3.3845964555988943    2.849385795522572   ]
#   [ 0.22112006793345843   2.849385795522572     3.184030778920848   ]]
#
#  [[ 1.639408679269624     2.306802395979563    -1.5471238721430736  ]
#   [ 2.306802395979563     3.7543543267703505   -2.1801250820921236  ]
#   [-1.5471238721430736   -2.1801250820921236    1.8457169432580176  ]]
#
#  [[ 5.0631353460184645    1.5661943987162916   -0.9820409235605173  ]
#   [ 1.5661943987162916    0.6337569472325911   -0.7557534822914929  ]
#   [-0.9820409235605173   -0.7557534822914929    1.8972183025899603  ]]
#
#  [[ 0.01194205446643657   0.17304145299454773  -0.24079891518153854 ]
#   [ 0.17304145299454773   2.513117080488073    -3.4852594608970056  ]
#   [-0.24079891518153854  -3.4852594608970056    4.899013040996226   ]]
#
#  [[ 0.48187469159499746  -0.9166061369463511    0.03405233677407711 ]
#   [-0.9166061369463511    2.3186626408153574    1.4537807535668164  ]
#   [ 0.03405233677407711   1.4537807535668164    6.031172350328375   ]]
#
#  [[ 0.5272122048703974   -0.9277156458518647    0.9399711311693345  ]
#   [-0.9277156458518647    2.3443514298897243   -2.290717688616041   ]
#   [ 0.9399711311693345   -2.290717688616041     3.6022205549829187  ]]]

# %%
space.set_metric("AIRM")
d = [space.dist(S[i],S[i+1]) for i in range(len(S)-1)]
d
# Out:
# [5.955699403083108,
#  7.093135252517693,
#  6.795201082900157,
#  6.1216264758770915,
#  5.7841856096903115,
#  5.298273170330889,
#  13.283043485504084,
#  12.125849793106141,
#  2.877682796165527]

# %%
space.set_metric("Euclidean")
d = [space.dist(S[i],S[i+1]) for i in range(len(S)-1)]
d
# Out:
# [4.195508844700247,
#  4.466453462342294,
#  4.290626440332101,
#  6.277210635650322,
#  8.358952690149541,
#  5.220727102733243,
#  7.611724856786275,
#  7.27010457671465,
#  5.965457565147796]

# %%
space.convex_combination(S[0], S[1], t=0.2)
# Out:
# array([[ 0.1742604978826786 , -0.31788665822257856,  0.19208879514693106],
#        [-0.31788665822257856,  3.0854445636206225 ,  1.6156247402972814 ],
#        [ 0.19208879514693106,  1.6156247402972814 ,  2.607011414499006  ]])
